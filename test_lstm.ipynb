# %% [markdown]
# # LSTM test

# %%
# https://towardsdatascience.com/lstms-in-pytorch-528b0440244

# %%
import torch as th
import torch.nn as nn

import matplotlib.pyplot as plt

# %%
from pred_model.lstm import LSTMModel

# %%
x_points = th.arange(0, 100, 0.01)

# %%
y_points = th.sin(x_points)

# %%
plt.plot(x_points, y_points)
plt.show()

# %%
lstm = LSTMModel(1, 10, 10, 1, 0.01)
